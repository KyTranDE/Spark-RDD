# %% [markdown]
# # ***Transformation Lazy***
# - ***Transformation*** :
#     - ***RDD1 = load() data from DataLake to Memory***
#     - ***RDD2 = RDD1.groupby()***
#     - ***RDD3 = RDD2.filter()***
# - **Action** :
#     - **RDD3.show()**
#
# - ***Spark transformation*** thể hiện ***lazy*** ở chỗ là khi chưa có **acction** nào xảy ra thì không có ***transformation*** nào được thực thi cả ***Spark*** cứ đợi chừng nào có ***acction*** thì ***Spark*** mới phân tích các ***transformation*** và thực thi nó .

# %% [markdown]
# ![image.png](attachment:image.png)
